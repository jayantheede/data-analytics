# %% [markdown]
# <a href="https://colab.research.google.com/github/jayantheede/data-analytics/blob/main/school.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/record_layout.csv')

# %%
df.head()
# Out:
#    Field Number        Field Name  \
# 0           1.0               uid
# 1           2.0    nces_school_id
# 2           3.0       school_name
# 3           4.0  nces_district_id
# 4           5.0     district_name
#
#                                          Description Variable Definition
# 0                                  Unique identifier      NaN        NaN
# 1  National Center for Education Statistics uniqu...      NaN        NaN
# 2                                     Name of school      NaN        NaN
# 3  National Center for Education Statistics uniqu...      NaN        NaN
# 4                            Name of school district      NaN        NaN

# %%
df.tail()
# Out:
#     Field Number Field Name Description Variable  \
# 71           NaN        NaN         NaN       32
# 72           NaN        NaN         NaN       33
# 73           NaN        NaN         NaN       41
# 74           NaN        NaN         NaN       42
# 75           NaN        NaN         NaN       43
#
#                                            Definition
# 71  Town, Distant Territory inside an urban cluste...
# 72  Town, Remote Territory inside an urban cluster...
# 73  Rural, Fringe Census-defined rural territory t...
# 74  Rural, Distant Census-defined rural territory ...
# 75  Rural, Remote Census-defined rural territory t...

# %%
df.isnull().sum()
# Out:
# Field Number    26
# Field Name      26
# Description     26
# Variable        42
# Definition      42
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 4

# %%
df.size
# Out:
# 380

# %%
df.shape
# Out:
# (76, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Field Number  50 non-null     float64
#  1   Field Name    50 non-null     object
#  2   Description   50 non-null     object
#  3   Variable      34 non-null     object
#  4   Definition    34 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 3.1+ KB

# %%
df.value_counts()
# Out:
# Field Number  Field Name               Description                                                                                                  Variable    Definition
# 18.0          shooting_type            Type of shooting                                                                                             accidental  Gun discharged accidentally                                                                                       1
# 20.0          gender_shooter1          Gender of first shooter                                                                                      a           Asian                                                                                                             1
# ...

# %%
df.columns
# Out:
# Index(['Field Number', 'Field Name', 'Description', 'Variable', 'Definition'], dtype='object')

# %%
df.nunique()
# Out:
# Field Number    50
# Field Name      50
# Description     50
# Variable        25
# Definition      27
# dtype: int64

# %%
df.dtypes
# Out:
# Field Number    float64
# Field Name       object
# Description      object
# Variable         object
# Definition       object
# dtype: object

# %%
import seaborn as sns
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.drop_duplicates()
# Out:
#     Field Number        Field Name  \
# 0            1.0               uid
# 1            2.0    nces_school_id
# 2            3.0       school_name
# 3            4.0  nces_district_id
# 4            5.0     district_name
# ..           ...               ...
# 71           NaN               NaN
# 72           NaN               NaN
# 73           NaN               NaN
# 74           NaN               NaN
# 75           NaN               NaN
#
#                                           Description Variable  \
# 0                                   Unique identifier      NaN
# 1   National Center for Education Statistics uniqu...      NaN
# 2                                      Name of school      NaN
# 3   National Center for Education Statistics uniqu...      NaN
# 4                             Name of school district      NaN
# ..                                                ...      ...
# 71                                                NaN       32
# ...

# %%
df.drop_duplicates(inplace=True)
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Field Number, Field Name, Description, Variable, Definition]
# Index: []

# %%
df.isnull()
# Out:
#     Field Number  Field Name  Description  Variable  Definition
# 0          False       False        False      True        True
# 1          False       False        False      True        True
# 2          False       False        False      True        True
# 3          False       False        False      True        True
# 4          False       False        False      True        True
# ..           ...         ...          ...       ...         ...
# 71          True        True         True     False       False
# 72          True        True         True     False       False
# 73          True        True         True     False       False
# 74          True        True         True     False       False
# 75          True        True         True     False       False
#
# [72 rows x 5 columns]

# %%
df["Field Name"]
# Out:
# 0                  uid
# 1       nces_school_id
# 2          school_name
# 3     nces_district_id
# 4        district_name
#             ...
# 71                 NaN
# 72                 NaN
# 73                 NaN
# 74                 NaN
# 75                 NaN
# Name: Field Name, Length: 72, dtype: object

# %%
df[df['Field Name'].isin(['True'])]
# Out:
# Empty DataFrame
# Columns: [Field Number, Field Name, Description, Variable, Definition]
# Index: []
